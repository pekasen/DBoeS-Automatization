# %%
import pandas as pd

# %%
csv_path = 'Parlamentarier.csv'

# %%
df = pd.read_csv(csv_path, dtype=str)
df
# Out:
#                                         id                    Kategorie  \
# 0     7e5f869d-1663-45a5-a4a8-a2816da16c71  Abgeordnetenhaus von Berlin
# 1     69e41caa-b889-418b-a70b-f7655244f9d2  Abgeordnetenhaus von Berlin
# 2     4daa4f79-91dd-48c9-aea7-ebcb2ffae570  Abgeordnetenhaus von Berlin
# 3     643fe279-9336-45a0-bd2c-36d14dfe43aa  Abgeordnetenhaus von Berlin
# 4     08e2859f-8ee3-48a2-9931-a8bec0a12dd6  Abgeordnetenhaus von Berlin
# ...                                    ...                          ...
# 2676  89e00760-835f-4d61-bb83-6f498a379f96            Thüringer Landtag
# 2677  28094ed3-2ea7-4b4d-8d0a-271da4f8a093            Thüringer Landtag
# 2678  e625f167-0b57-4861-8da3-a8e8ea8435de            Thüringer Landtag
# 2679  2cff04e6-2293-4a26-926d-603ff625b79e            Thüringer Landtag
# 2680  0b5dd87d-bb03-4225-8268-ab8e2249fe12            Thüringer Landtag
#
#                    Name Partei                         Wahlkreis Geschlecht  \
# ...

# %%
ids = df['SM_Twitter_id']
ids
# Out:
# 0                      NaN
# 1                      NaN
# 2       826402742893760512
# 3       791978053379432448
# 4                262062333
#                ...
# 2676    874540143461511168
# 2677    964949052411572224
# 2678    827151378195824640
# 2679            2261267142
# 2680                   NaN
# Name: SM_Twitter_id, Length: 2681, dtype: object

# %%
ids.dropna(inplace=True)
ids
# Out:
# 2        826402742893760512
# 3        791978053379432448
# 4                 262062333
# 5                2684648481
# 6       1073175051451752448
#                ...
# 2675             3290227454
# 2676     874540143461511168
# 2677     964949052411572224
# 2678     827151378195824640
# 2679             2261267142
# Name: SM_Twitter_id, Length: 1471, dtype: object

# %%
ids.to_csv(f'twitter_ids_{csv_path}', index=False, header=False)

# %%
# !head 'twitter_ids_{csv_path}'
# Out:
# 826402742893760512
# 791978053379432448
# 262062333
# 2684648481
# 1073175051451752448
# 67401154
# 393541223
# 2967515615
# 977505094399873024
# 2359728006
